# %% [markdown]
# ### SVM

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import os
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
DATADIR = '/home/lenin/Documents/kaggle/color_classification/ColorClassification'
CATEGORIES = ['Black','Blue','Brown','Green','orange','red','Violet','White','yellow']
IMG_SIZE=100

# %%
#verifico que reconozca los directorios y obtenga la imagen
#recorro ciclos una sola vez
for category in CATEGORIES:
    path=os.path.join(DATADIR, category)
    for img in os.listdir(path):
        img_array=cv2.imread(os.path.join(path,img))
        plt.imshow(img_array)
        plt.show()
        break
    break

# %%
training_data=[]
def create_training_data():
    for category in CATEGORIES:
        path=os.path.join(DATADIR, category)
        class_num=category
        for img in os.listdir(path):
            try:
                img_array=cv2.imread(os.path.join(path,img))
                new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                training_data.append([new_array,class_num])
            except Exception as e:
                pass
create_training_data()

# %%
print(len(training_data))
# Out:
# 117

# %%
#legth del totol de datos train para usarlos despues
lenofimage = len(training_data)

# %%
X=[]
y=[]

for categories, label in training_data:
    X.append(categories)
    y.append(label)
X= np.array(X).reshape(lenofimage,-1)
#X = tf.keras.utils.normalize(X, axis = 1)

# %%
X = X/255.0
y=np.array(y)
print(y.shape)
print(X.shape)
# Out:
# (117,)
# (117, 30000)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
svc = SVC(kernel='linear',gamma='auto')
svc.fit(X_train, y_train)
# Out:
# SVC(gamma='auto', kernel='linear')

# %%
y2 = svc.predict(X_test)

# %%
print("Accuracy on unknown data is",accuracy_score(y_test,y2))
# Out:
# Accuracy on unknown data is 0.8333333333333334

# %%
print("Accuracy on unknown data is",classification_report(y_test,y2))
# Out:
# Accuracy on unknown data is               precision    recall  f1-score   support
#
#        Black       1.00      0.25      0.40         4
#         Blue       0.67      1.00      0.80         2
#        Brown       1.00      0.86      0.92         7
#        Green       1.00      1.00      1.00         2
#       Violet       0.71      1.00      0.83         5
#        White       0.83      1.00      0.91         5
#       orange       1.00      0.50      0.67         2
#          red       1.00      1.00      1.00         3
#       yellow       0.00      0.00      0.00         0
#
#     accuracy                           0.83        30
#    macro avg       0.80      0.73      0.73        30
# weighted avg       0.90      0.83      0.82        30
# /home/lenin/Apps/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/lenin/Apps/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/lenin/Apps/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
result = pd.DataFrame({'original' : y_test,'predicho' : y2})
result
# Out:
#    original predicho
# 0     Brown    Brown
# 1    orange   orange
# 2     Brown    Brown
# 3     Brown    White
# 4       red      red
# 5      Blue     Blue
# 6       red      red
# 7    Violet   Violet
# 8     White    White
# 9      Blue     Blue
# 10    Black   Violet
# 11    Black   Violet
# 12    Black     Blue
# 13   Violet   Violet
# 14    Brown    Brown
# 15   Violet   Violet
# 16    White    White
# 17      red      red
# 18    White    White
# 19    White    White
# 20   Violet   Violet
# 21    Brown    Brown
# 22    White    White
# 23    Green    Green
# 24   orange   yellow
# 25    Green    Green
# 26   Violet   Violet
# 27    Black    Black
# 28    Brown    Brown
# 29    Brown    Brown

# %%
img=cv2.imread(os.path.join('/home/lenin/Documents/kaggle/color_classification/ColorClassification/testimg/','2.jpg'))
x=cv2.resize(img,(IMG_SIZE,IMG_SIZE))
x = np.reshape(x, (1, -1))
x=x/255.0
plt.imshow(img)
plt.show()
print(x.shape)
resp = svc.predict(X=x)
print(resp)
# Out:
# (1, 30000)
# ['Green']
