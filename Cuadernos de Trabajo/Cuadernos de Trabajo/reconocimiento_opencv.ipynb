# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2900/1574637352.py in <module>
# ----> 1 QtCore.qInstallMessageHandler(None)
#       2 import cv2
#
# NameError: name 'QtCore' is not defined

# %%
import cv2
#face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
face_cascade = cv2.CascadeClassifier('cascade_funciona_mal.xml')
#face_cascade = cv2.CascadeClassifier('cascade_joao.xml')
cap = cv2.VideoCapture(0)

while (True):
    _, img = cap.read() #aqui la camara captura un frame
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    #faces = face_cascade.detectMultiScale(gray, scaleFactor = 5, minNeighbors = 20, minSize=(24,16))
    faces = face_cascade.detectMultiScale(gray, scaleFactor = 6, minNeighbors = 15, minSize=(24,16))
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0), 2)
    cv2.imshow('img',img)
    k = cv2.waitKey(30)
    if k == 27: 
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x178b910) is not the object's thread (0x20d3f30).
# Cannot move to target thread (0x178b910)
#
# QObject::moveToThread: Current thread (0x178b910) is not the object's thread (0x20d3f30).
# Cannot move to target thread (0x178b910)
#
# QObject::moveToThread: Current thread (0x178b910) is not the object's thread (0x20d3f30).
# Cannot move to target thread (0x178b910)
#
# QObject::moveToThread: Current thread (0x178b910) is not the object's thread (0x20d3f30).
# Cannot move to target thread (0x178b910)
#
# QObject::moveToThread: Current thread (0x178b910) is not the object's thread (0x20d3f30).
# Cannot move to target thread (0x178b910)
#
# QObject::moveToThread: Current thread (0x178b910) is not the object's thread (0x20d3f30).
# Cannot move to target thread (0x178b910)
#
# QObject::moveToThread: Current thread (0x178b910) is not the object's thread (0x20d3f30).
# Cannot move to target thread (0x178b910)
#
# ...

# %%
# metodo 2 para probar modelo
import cv2

# %%
cap = cv2.VideoCapture(0,cv2.CAP_DSHOW)

majinBooClassif = cv2.CascadeClassifier('cascade_funciona_mal.xml')

while True:
    
    ret,frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    toy = majinBooClassif.detectMultiScale(gray,
    scaleFactor = 5,
    minNeighbors = 91,
    minSize=(70,78))

    for (x,y,w,h) in toy:
        cv2.rectangle(frame, (x,y),(x+w,y+h),(0,255,0),2)
        cv2.putText(frame,'casco',(x,y-10),2,0.7,(0,255,0),2,cv2.LINE_AA)

    cv2.imshow('frame',frame)
    
    if cv2.waitKey(1) == 27:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_2900/2102457330.py in <module>
#       6
#       7     ret,frame = cap.read()
# ----> 8     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       9
#      10     toy = majinBooClassif.detectMultiScale(gray,
#
# error: OpenCV(4.7.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import cv2
import numpy as np 
import imutils 
import os

# %%
Datos = 'n'
if not os.path.exists(Datos):
    print('carpeta creada: ',Datos)
    os.makedirs(Datos) 
cap = cv2.VideoCapture(0)
x1, y1 = 200, 80
x2, y2 = x1+300, y1+300
count=0
while (True):
    ret, frame = cap.read()
    if ret == False: break 
    aux = frame.copy()
    cv2.rectangle(frame, (x1,y1), (x2, y2), (255,0,0), 2)
    objeto = aux[y1:y2,x1:x2]
    objeto = imutils.resize(objeto, width=38)
    cv2.imshow('frame',frame)
    cv2.imshow('objeto',objeto)
    k=cv2.waitKey(1)
    if k == 27: break 
    if k == ord('s'): 
        Datos='/home/lenin/Documents/GitHub/CursoPython/Cuadernos de Trabajo/Cuadernos de Trabajo/n/img_{}.jpg'.format(count)
        cv2.imwrite(Datos, objeto)
        print('img saved: ',Datos)
        count+=1
cap.release()
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x1e5fb70) is not the object's thread (0x270c4c0).
# Cannot move to target thread (0x1e5fb70)
#
# QObject::moveToThread: Current thread (0x1e5fb70) is not the object's thread (0x270c4c0).
# Cannot move to target thread (0x1e5fb70)
#
# QObject::moveToThread: Current thread (0x1e5fb70) is not the object's thread (0x270c4c0).
# Cannot move to target thread (0x1e5fb70)
#
# QObject::moveToThread: Current thread (0x1e5fb70) is not the object's thread (0x270c4c0).
# Cannot move to target thread (0x1e5fb70)
#
# QObject::moveToThread: Current thread (0x1e5fb70) is not the object's thread (0x270c4c0).
# Cannot move to target thread (0x1e5fb70)
#
# QObject::moveToThread: Current thread (0x1e5fb70) is not the object's thread (0x270c4c0).
# Cannot move to target thread (0x1e5fb70)
#
# QObject::moveToThread: Current thread (0x1e5fb70) is not the object's thread (0x270c4c0).
# Cannot move to target thread (0x1e5fb70)
#
# ...
